# %%
def generate_table_creation_statements(json_data, parent_key=None):
    statements = []

    if isinstance(json_data, dict):
        for key, value in json_data.items():
            new_parent_key = f"{parent_key}_{key}" if parent_key else key
            statements.extend(generate_table_creation_statements(value, new_parent_key))

    elif isinstance(json_data, list):
        for item in json_data:
            statements.extend(generate_table_creation_statements(item, parent_key))

    elif isinstance(json_data, int):
        statements.append(f"{parent_key} INT,")

    elif isinstance(json_data, str):
        statements.append(f"{parent_key} VARCHAR(255),")

    elif isinstance(json_data, float):
        statements.append(f"{parent_key} FLOAT,")

    elif isinstance(json_data, bool):
        statements.append(f"{parent_key} BOOLEAN,")

    elif json_data is None:
        statements.append(f"{parent_key} NULL,")

    return statements

# Example JSON data
example_json_data = [
    
  {
  "00000000@mail*wit*ie": {
    "count": 12,
    "email": "00000000@mail.wit.ie",
    "id": "8c23c08d-8115-4c0a-ad49-4352ef7ac0a7",
    "last": "Tue Jan 16 2024 19:50:15 GMT+0000 (Greenwich Mean Time)",
    "nickname": "JohnDoe45",
    "picture": "https://avatars.githubusercontent.com/u/156776776663?v=4",
    "title": "Programming Fundamentals",
    "topic-00-induction": {
      "book-induction": {
        "01": {
          "last": "1/15/2024, 9:15:50 PM",
          "title": "Induction",
          "visits": 1
        },
        "02": {
          "last": "1/15/2024, 9:15:50 PM",
          "title": "Induction",
          "visits": 1
        },
        "03": {
          "last": "1/15/2024, 9:15:50 PM",
          "title": "Induction",
          "visits": 1
        },
        "04": {
          "last": "1/15/2024, 9:15:50 PM",
          "title": "Induction",
          "visits": 1
        },
        "05": {
          "last": "1/15/2024, 9:15:50 PM",
          "title": "Induction",
          "visits": 1
        },
        "06": {
          "last": "1/15/2024, 9:15:50 PM",
          "title": "Induction",
          "visits": 1
        },
        "Exercises": {
          "count": 1,
          "last": "1/16/2024, 7:47:19 PM",
          "title": "Induction",
          "visits": 3
        },
        "Induction": {
          "count": 1,
          "last": "1/16/2024, 7:47:19 PM",
          "title": "Induction",
          "visits": 3
        },
        "IntelliJ": {
          "count": 1,
          "last": "1/16/2024, 7:47:19 PM",
          "title": "Induction",
          "visits": 3
        },
        "Software": {
          "count": 1,
          "last": "1/16/2024, 7:47:19 PM",
          "title": "Induction",
          "visits": 3
        },
        "Solutions": {
          "count": 1,
          "last": "1/16/2024, 7:47:19 PM",
          "title": "Induction",
          "visits": 3
        }
      },
      "talk-00": {
        "count": 1,
        "last": "1/16/2024, 7:47:19 PM",
        "title": "Induction",
        "visits": 3
      },
      "talk-1": {
        "count": 2,
        "last": "1/16/2024, 7:47:21 PM"
      },
      "talk-2": {
        "count": 7,
        "last": "1/16/2024, 7:47:41 PM",
        "title": "Introduction to the PDE",
        "visits": 4,
        "title": "00: Induction",
        "visits": 10
      }
    },
    "topic-00-overview": {
      "unit-a-course-review": {
        "talk-1-overview": {
          "count": 1,
          "last": "1/16/2024, 7:50:43 PM",
          "title": "All labs in Module",
          "visits": 4
        }
      }
    }
  },
  "1111111111@mail*wit*ie": {
    "count": 12,
    "email": "00000000@mail.wit.ie",
    "id": "8c23c08d-8115-4c0a-ad49-4352ef7ac0a7",
    "last": "Tue Jan 16 2024 19:50:15 GMT+0000 (Greenwich Mean Time)",
    "nickname": "JohnDoe45",
    "picture": "https://avatars.githubusercontent.com/u/156776776663?v=4",
    "title": "Programming Fundamentals",
    "topic-00-induction": {
      "book-induction": {
        "01": {
          "last": "1/15/2024, 9:15:50 PM",
          "title": "Induction",
          "visits": 1
        },
        "02": {
          "last": "1/15/2024, 9:15:50 PM",
          "title": "Induction",
          "visits": 1
        },
        "03": {
          "last": "1/15/2024, 9:15:50 PM",
          "title": "Induction",
          "visits": 1
        },
        "04": {
          "last": "1/15/2024, 9:15:50 PM",
          "title": "Induction",
          "visits": 1
        },
        "05": {
          "last": "1/15/2024, 9:15:50 PM",
          "title": "Induction",
          "visits": 1
        },
        "06": {
          "last": "1/15/2024, 9:15:50 PM",
          "title": "Induction",
          "visits": 1
        },
        "Exercises": {
          "count": 1,
          "last": "1/16/2024, 7:47:19 PM",
          "title": "Induction",
          "visits": 3
        },
        "Induction": {
          "count": 1,
          "last": "1/16/2024, 7:47:19 PM",
          "title": "Induction",
          "visits": 3
        },
        "IntelliJ": {
          "count": 1,
          "last": "1/16/2024, 7:47:19 PM",
          "title": "Induction",
          "visits": 3
        },
        "Software": {
          "count": 1,
          "last": "1/16/2024, 7:47:19 PM",
          "title": "Induction",
          "visits": 3
        },
        "Solutions": {
          "count": 1,
          "last": "1/16/2024, 7:47:19 PM",
          "title": "Induction",
          "visits": 3
        }
      },
      "talk-00": {
        "count": 1,
        "last": "1/16/2024, 7:47:19 PM",
        "title": "Induction",
        "visits": 3
      },
      "talk-1": {
        "count": 2,
        "last": "1/16/2024, 7:47:21 PM"
      },
      "talk-2": {
        "count": 7,
        "last": "1/16/2024, 7:47:41 PM",
        "title": "Introduction to the PDE",
        "visits": 4,
        "title": "00: Induction",
        "visits": 10
      }
    },
    "topic-00-overview": {
      "unit-a-course-review": {
        "talk-1-overview": {
          "count": 1,
          "last": "1/16/2024, 7:50:43 PM",
          "title": "All labs in Module",
          "visits": 4
        }
      }
    }
  }
}

]

# Generate table creation statements
table_creation_statements = generate_table_creation_statements(example_json_data)

# Print the generated SQL statements
for statement in table_creation_statements:
    print(statement)
# Out:
# 00000000@mail*wit*ie_count INT,
# 00000000@mail*wit*ie_email VARCHAR(255),
# 00000000@mail*wit*ie_id VARCHAR(255),
# 00000000@mail*wit*ie_last VARCHAR(255),
# 00000000@mail*wit*ie_nickname VARCHAR(255),
# 00000000@mail*wit*ie_picture VARCHAR(255),
# 00000000@mail*wit*ie_title VARCHAR(255),
# 00000000@mail*wit*ie_topic-00-induction_book-induction_01_last VARCHAR(255),
# 00000000@mail*wit*ie_topic-00-induction_book-induction_01_title VARCHAR(255),
# 00000000@mail*wit*ie_topic-00-induction_book-induction_01_visits INT,
# 00000000@mail*wit*ie_topic-00-induction_book-induction_02_last VARCHAR(255),
# 00000000@mail*wit*ie_topic-00-induction_book-induction_02_title VARCHAR(255),
# 00000000@mail*wit*ie_topic-00-induction_book-induction_02_visits INT,
# 00000000@mail*wit*ie_topic-00-induction_book-induction_03_last VARCHAR(255),
# 00000000@mail*wit*ie_topic-00-induction_book-induction_03_title VARCHAR(255),
# 00000000@mail*wit*ie_topic-00-induction_book-induction_03_visits INT,
# ...
